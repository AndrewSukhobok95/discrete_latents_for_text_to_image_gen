# %%
import numpy as np
from matplotlib import pyplot as plt
from torchvision import transforms as torch_transforms
import torchvision.transforms.functional as TF

import sys
sys.path.append('./../../')

from datasets.cub_loader import CUBData
from datasets.common import SquarePad
from datasets.mnist_loader import MNISTData
from utilities.md_mnist_utils import LabelsInfo
from notebooks.utils import show

# %%
data_source_1 = CUBData(
    img_type='128_text',
    root_path='/u/82/sukhoba1/unix/Desktop/TA-VQVAE/data/CUB/',
    batch_size=64,
    description_len=66,
    custom_transform_version=0,
    prct_train_split=0.99)

loader_1 = data_source_1.get_train_loader(16)

imgs, texts = next(iter(loader_1))

show(imgs, figsize=(32,32), plot_grid=True)

# %%
data_source_2 = CUBData(
    img_type='128_text',
    root_path='/u/82/sukhoba1/unix/Desktop/TA-VQVAE/data/CUB/',
    batch_size=64,
    description_len=66,
    custom_transform_version=1,
    prct_train_split=0.99)

loader_2 = data_source_2.get_train_loader(16)

imgs, texts = next(iter(loader_2))

show(imgs, figsize=(32,32), plot_grid=True)

# %%
data_source_3 = CUBData(
    img_type='32_text',
    root_path='/u/82/sukhoba1/unix/Desktop/TA-VQVAE/data/CUB/',
    batch_size=64,
    description_len=66,
    custom_transform_version=1,
    prct_train_split=0.99)

loader_3 = data_source_3.get_train_loader(16)

imgs, texts = next(iter(loader_3))

show(imgs, figsize=(32,32), plot_grid=True)
